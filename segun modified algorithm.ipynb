# %% [markdown]
# ## Thanks for sharing, it kept me busy all day

# %%
# your code

# while loop example: while loop is used when we don't know the possible number of iterations

#Guessing die game

from random import randint

n = randint(1,6) #n = random number
a = 0
while a != n:
    a = int(input('Enter number between 1 and 6:\n')) #a = your guess
    if n > 0: # i dont understand why this was there 
        if a > n:
            print('Number is too large')
        elif a < n:
            print('Number is too small')
    else:
        print('Enter a positive number between 1 and 6 next time')
        
else:
    print('Congrats')

# %% [markdown]
# ## my code run perfectly without  (if n > 0:)

# %%
# muhammad code

# while loop example: while loop is used when we don't know the possible number of iterations

#Guessing die game

from random import randint 

n = randint(1,6)

k = 0
while k != n:
    x = int(input("Guess the die number: "))

    if x < n:
        print ("your guessed was too low\n")
       
    elif x > n:
        print ("your guessed was too high\n")
        
    else:
        print("you got it")
        break

# %% [markdown]
# ## I USED ANOTHER METHOD TO COUNT THE NUMBER OF TRIALS, see below

# %%
#Muhammad code

# using the while loop to create an ATM code

#1. create the security system (the PIN)

print('Welcome to Ikhlas Islamic Bank ATM')

pin_trial = 0

while pin_trial <= 3:
    pin = int(input('Please enter your 4-digit PIN:\n'))
    if pin == 1234:
        print('PIN is correct')
        break
        
    elif pin != 1234:
        print('Incorrect PIN')
        pin_trial += 1
        if pin_trial == 3:
            print('\n Card blocked. Contact your bank for further details.')
            break
# Out:
# Welcome to Ikhlas Islamic Bank ATM
# Enter your 4 digit PIN:
# 4
# Incorrect PIN
# Enter your 4 digit PIN:
# 4
# Incorrect PIN
# Enter your 4 digit PIN:
# 4
# Incorrect PIN
# Card blocked. Contact your bank for further details.

# %% [markdown]
# ## PLS CHECK THE BUTTOM FOR THE COMMENT ON ATM CODE

# %%
# your code

# using the while loop to create an ATM code

#3 create transactions

print('WELCOME TO SEGUN FINANCIAL BANK (SFB) ATM')
home_page = 'Y'
pin_trial = 3
balance = 250999.76

while pin_trial >= 0:
    pin = int(input('Please enter your 4-digit PIN:\n(Enter 0000 to cancel)\n'))
    if pin == 1234:
        print('PIN is correct\n')
        while home_page not in ('No', 'N', 'no', 'n', 'nay'):
            print('\nWhat transaction do you want to perform?\n')
            print('Enter 1: To check balance\nEnter 2: To make withdrawal\nEnter 3: To send money\nEnter 4: To deposit money\nEnter 5: To cancel transaction')
            choice = int(input('Enter code for transaction:\n'))
            
            if choice == 1:
                print('\nYour current balance is $' + str(balance))
                home_page = input('Would you like to perform another transaction?\n')
                if home_page in ('No', 'N', 'no', 'n', 'nay'):
                    print('\nThank You for using SFB ATM.')
                    break
                    
            elif choice == 2:
                withdrawal = float(input('Enter amount to withdraw: $100, $200, $500, $1000, $10000\n'))
                if withdrawal in range(100, 10001):
                    print('\nPlease take your cash\n')
                    balance = balance - withdrawal
                    print('TRANSACTION SUCCESSFUL\nYour new balance is $' + str(balance))
                    home_page = input('Would you like to perform another transaction?\n')
                    if home_page in ('No', 'N', 'no', 'n', 'nay'):
                        print('\nThank You for using SFB ATM.')
                        break
                else:
                    print('Invalid amount... Can only dispense amounts within $100 and $10000\nTransaction declined')
                    home_page = 'Y'
                    
            elif choice == 3:
                bank = input("Enter Recipient's bank: GTB, FBN, UBA, ZENITH, UNION\n")
                account_no = input("Enter recipient's 10-digit acct:\n")
                if len(account_no) != 10:
                    print('TRANSACTION DECLINED...Invalid account number\n')
                    home_page = 'Y'
                else:
                    amount = float(input("Enter amount to send:\n"))
                    if amount == 0:
                        print('TRANSACTION DECLINED...Invalid amount')
                        home_page = 'Y'
                    
                    elif amount > balance:
                        print('TRANSACTION DECLINED...Insufficient funds')
                        home_page = 'Y'
                    
                    else:
                        confirmation = input('Do you want to transfer $' + str(amount) + ' to ' + bank.title() + ' ' + str(account_no) + '?\n')
                        if confirmation in ('Yes', 'Y', 'yes', 'y', 'yeah'):
                            print('\nTRANSACTION SUCCESSFUL')
                            balance = balance - amount
                            print('Your new balance is $' + str(balance))
                            home_page = input('Would you like to perform another transaction?\n')
                            if home_page in ('No', 'N', 'no', 'n', 'nay'):
                                print('\nThank You for using SFB ATM.')
                                break
                        else:
                            print('TRANSACTION DECLINED')
                            home_page = 'Y'
                            
            elif choice == 4:
                print('\nThis machine accepts deposits only in $100, $500 and $1000 notes')
                amount = int(input('Enter which currency notes you want to deposit:\n'))
                if amount in (100, 500, 1000):
                    num_notes = int(input("How many notes are you depositing (max of 20 notes):\n"))
                    if num_notes == 0 or num_notes > 20 :
                        print('TRANSACTION DECLINED...Invalid number of notes\n')
                        home_page = 'Y'
                    else:
                        total_amount = amount * num_notes
                        balance = balance + total_amount
                        print('\nTRANSACTION SUCCESSFUL')
                        print('\nYour new balance is $' + str(balance))
                        home_page = input('Would you like to perform another transaction?\n')
                        if home_page in ('No', 'N', 'no', 'n', 'nay'):
                            print('\nThank You for using SFB ATM.')
                            break    
                else:
                    print('TRANSACTION DECLINED')
                    home_page = 'Y'
                    
            elif choice == 5:
                print('\nPlease remove your card')
                print('\nThank You for using SFB ATM.')
                break
                
    elif pin == 0000:
        break
        
    elif pin != 1234 or pin != 0000:
        print('Incorrect PIN')
        pin_trial = pin_trial - 1
        if pin_trial == 0:
            print('\nCard blocked. Contact your bank for further details.')
            break
            
##observation while running the code

# 1. after the first,second or third transaction as the may be, if i am asked (would you like to perfrom another 
#   transaction?) and i choose "no". The system will still as me for pin 
#    (a) if i then enter the correct pin "1234", it will display correct without allowing me to perform any transaction.

## Modification -----> I changed the code where by if i enter "no" after displaying the question (would you like to perfrom 
#                      another transaction?) the program stop completing.

## 2. I added the savings and current option, although it make no difference because we dont enough resources  to do so.
## 3. I added another option to recharge.

# %% [markdown]
# ## This is the modified code

# %%
# muhammad modified code

# using the while loop to create an ATM code

#3 create transactions

print('WELCOME TO SEGUN FINANCIAL BANK (SFB) ATM')
home_page = 'Y'
k = 0
pin_trial = 3
balance = 250999.76

while pin_trial >= 0 and k == 0:
    pin = int(input('Please enter your 4-digit PIN:\n(Enter 0000 to cancel)\n'))
    if pin == 1234:
        print('PIN is correct\n')
        
        while home_page == "Y":
            print('\nWhat transaction do you want to perform?\n')
            print('Enter 1: To check balance\nEnter 2: To make withdrawal\nEnter 3: To send money\nEnter 4: To deposit money\nEnter 5: To recharge\nEnter 6: To cancel transaction')
            choice = int(input('Enter code for transaction:\n'))
            
            if choice == 1:
                print('\nYour current balance is $' + str(balance))
                home_page = input('Would you like to perform another transaction? Y/N\n')
                if home_page == "N":
                    k = 1 #to cancel the transaction
                    print('\nPlease take your card. \nThank You for using SFB ATM.')
                    
                    
            elif choice == 2:
                withdrawal = float(input('Enter amount to withdraw: $100, $200, $500, $1000, $10000\n'))
                if withdrawal in range(100, 100001):
                    print('\nPlease take your cash\n')
                    balance = balance - withdrawal
                    print('TRANSACTION SUCCESSFUL\nYour new balance is $' + str(balance))
        
                    home_page = input('Would you like to perform another transaction? Y/N\n')
                    if home_page == "N":
                        k = 1 #to cancel the transaction
                        print('\nPlease take your card. \nThank You for using SFB ATM.')     
                else:
                    print('Invalid amount... Can only dispense amounts within $100 and $10000\nTransaction declined')
                    
                    
            elif choice == 3:
                bank = input("Enter Recipient's bank: GTB, FBN, UBA, ZENITH, UNION\n")
                account_spec = int(input("Enter 1: for savings \nEnter 2: for current:\n"))
                if account_spec not in range(1,3):
                    k=1
                    print ("Wrong entry!")
                    
                else: 
                    account_no = input("Enter recipient's 10-digit acct:\n")
                    if len(account_no) != 10:
                        print('TRANSACTION DECLINED...Invalid account number\n')
                    
                    else:
                        amount = float(input("Enter amount to send:\n"))
                        if amount == 0:
                            print('TRANSACTION DECLINED...Invalid amount')
                        
                    
                        elif amount > balance:
                            print('TRANSACTION DECLINED...Insufficient funds')
                        
                    
                        else:
                            confirmation = input('Do you want to transfer $' + str(amount) + ' to ' + bank.title() + ' ' + str(account_no) + '?\n')
                            if confirmation in ('Yes','YES', 'Y', 'yes', 'y', 'yeah'):
                                print('\nTRANSACTION SUCCESSFUL')
                                balance = balance - amount
                                print('Your new balance is $' + str(balance))
                                home_page = input('Would you like to perform another transaction? Y/N\n')
                                if home_page == "N":
                                    k = 1 #to cancel the transaction
                                    print('\nPlease take your card. \nThank You for using SFB ATM.')
                            
                            else:
                                if confirmation in ('No','NO', 'N', 'no', 'n', 'nay'):
                                    print('TRANSACTION DECLINED')
                            
                            
            elif choice == 4:
                print('\nThis machine accepts deposits only in $100, $500 and $1000 notes')
                amount = int(input('Enter which currency notes you want to deposit:\n'))
                if amount in (100, 500, 1000):
                    num_notes = int(input("How many notes are you depositing (max of 20 notes):\n"))
                    if num_notes == 0 or num_notes > 20 :
                        print('TRANSACTION DECLINED...Invalid number of notes\n')
                        
                    else:
                        total_amount = amount * num_notes
                        balance = balance + total_amount
                        print('\nTRANSACTION SUCCESSFUL')
                        print('\nYour new balance is $' + str(balance))
                        home_page = input('Would you like to perform another transaction? Y/N\n')
                        if home_page == "N":
                            k = 1
                            print('\nPlease take your card. \nThank You for using SFB ATM.')
                    
                else:
                    print('TRANSACTION DECLINED')
                    
            elif choice == 5:
                Network = input("Enter your network: MTN, AIRTEL, GLO, ETISALAT")
                Mobile_No = input("Enter your mobile number: ")
                
                if len(Mobile_No) != 11:
                    print ("TRANSACTION DECLINED.....Invalid Mobile Number\n")
                    
                else:
                    amount = float(input("Enter the amount to recharge:\n "))
                    if amount == 0:
                        print ("TRANSACTION DECLINED....Invalid Amount\n")
                        
                    elif amount > balance:
                        print ("TRANSACTION DECLINED....Insufficient funds'\n")
                        
                    else:
                        confirmation = input("Do you want to transfer this $" + str(amount) + " to " +  Mobile_No + "?\n")
                        if confirmation in ('Yes','YES', 'Y', 'yes', 'y', 'yeah'):
                            print('\nTRANSACTION SUCCESSFUL')
                            balance = balance - amount
                            print('Your new balance is $' + str(balance))
                            home_page = input('Would you like to perform another transaction? Y/N\n')
                            if home_page == "N":
                                k = 1 #to cancel the transaction
                                print ('\nPlease take your card. \nThank You for using SFB ATM.')
                            
                        else:
                            if confirmation in ('No','NO', 'N', 'no', 'n', 'nay'):
                                print ('TRANSACTION DECLINED')              
                               
            elif choice == 6:
                k = 1
                print('\nPlease remove your card')
                print('\nThank You for using SFB ATM.')
                break
                
    elif pin == 0000:
        break
        
    elif pin != 1234 or pin != 0000:
        print('Incorrect PIN')
        pin_trial = pin_trial - 1
        if pin_trial == 0:
            print('\nCard blocked. Contact your bank for further details.')
            break

# %%
print('WELCOME')
pin_trial = 3
k = 0
restart = 'Y'
while pin_trial > 0 and k == 0:
    pin = int(input('enter pin'))
    if pin == 1234:
        print('How can we help you')
    
    elif pin == 0000:
        k = 1
        
    elif pin != 1234 or pin != 0000:
        pin_trial = pin_trial - 1
        print('You have ', pin_trial, ' trials left')
# Out:
# WELCOME
# enter pin1234
# How can we help you
# enter pin1233
# You have  2  trials left
# enter pin1222
# You have  1  trials left
